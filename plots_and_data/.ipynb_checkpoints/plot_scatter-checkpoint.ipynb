# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandasql as ps

dataset = pd.read_csv("dataset_concat.csv")

# %%
plt.rcParams['axes.titlesize'] = 15
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['text.usetex'] = False

# Function for a consistent length of figures of 84 mm, converting to inches
def new_figure(height=55):
    "Return figure with width 84mm and given height in mm."
    return plt.figure(figsize=(84/10.16, height/10.16))

# %%
dataset.head()
# Out:
#     Sort_Type Data_Type_or_List_type  List_length  Runtimes  \
# 0  merge_sort                 sorted           10  0.267837
# 1  merge_sort                 sorted           10  0.277732
# 2  merge_sort                 sorted           10  0.274984
# 3  merge_sort                 sorted           10  0.250366
# 4  merge_sort                 sorted           10  0.233188
#
#    Number_of_repeatitions                    Datetime
# 0                       7  2019-11-01 21:51:45.110982
# 1                       7  2019-11-01 21:51:45.110982
# 2                       7  2019-11-01 21:51:45.110982
# 3                       7  2019-11-01 21:51:45.110982
# 4                       7  2019-11-01 21:51:45.110982

# %%
filter = (dataset['List_length']==10485760)

df_ten_mil = pd.DataFrame( dataset[filter] )
df_ten_mil.reset_index( drop = True, inplace=True)


df_ten_mil['Single_runtime'] =  df_ten_mil['Runtimes']/df_ten_mil['Number_of_repeatitions']  
#Warning can be ignored
print( df_ten_mil.shape[0])
df_ten_mil.head()
# Out:
# 91
#     Sort_Type Data_Type_or_List_type  List_length    Runtimes  \
# 0  merge_sort                 sorted     10485760  421.490998
# 1  merge_sort                 sorted     10485760  562.105962
# 2  merge_sort                 sorted     10485760  382.834156
# 3  merge_sort                 sorted     10485760  378.748574
# 4  merge_sort                 sorted     10485760  469.247377
#
#    Number_of_repeatitions                    Datetime  Single_runtime
# 0                       7  2019-11-01 23:34:16.211564       60.213000
# 1                       7  2019-11-01 23:34:16.211564       80.300852
# 2                       7  2019-11-01 23:34:16.211564       54.690594
# 3                       7  2019-11-01 23:34:16.211564       54.106939
# 4                       7  2019-11-01 23:34:16.211564       67.035340

# %%
types_of_data= sorted( np.unique(df_ten_mil['Data_Type_or_List_type']).tolist() )
types_of_sorts=  np.unique(df_ten_mil['Sort_Type']).tolist() 
# print(types_of_data)
# print(types_of_sorts)

for data_type in types_of_data:
    fig = new_figure()
    filter01 = (df_ten_mil['Data_Type_or_List_type']==data_type)
    df_data_type = df_ten_mil[filter01]  
    
    for sort in types_of_sorts: 
        filter02 = (df_data_type['Sort_Type']==sort)
        plot_this = df_data_type[filter02] 
        
        plot_this.reset_index(drop=True, inplace=True)
        plt.plot( plot_this['Single_runtime'],'o',alpha=0.7, label=sort)
    plt.legend()    
    plt.xlabel('Index')
    plt.ylabel('Time in Seconds')
    plt.title("Runtimes for 10 million - "+data_type+" - data")
    plt.show()
