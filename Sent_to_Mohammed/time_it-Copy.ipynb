# %% [markdown]
# By: Bishnu Poudel, Mohammed Radwan

# %% [markdown]
# ## Benchmark Sorting Algorithms: Run timing and store in a data frame then pickle it

# %%
import nbimporter
from quick_sort import *

# %% [markdown]
# ## Create a data frame

# %%
import pandas as pd
import numpy as np
columns = ['Sort_Type','Data_Type_or_List_type','List_length','Runtimes','Number_of_repeatitions','Datetime']
df_ = pd.DataFrame( columns=columns)
df_
# Out:
# Empty DataFrame
# Columns: [Sort_Type, Data_Type_or_List_type, List_length, Runtimes, Number_of_repeatitions, Datetime]
# Index: []

# %% [markdown]
# ## Timeit function

# %%
import numpy as np
import timeit
import copy

def timing_function(number_of_data_points, sort_type, seed_number=12235):
    np.random.seed (seed_number)
    test_data = np.random.random(number_of_data_points ,)
    test_data = list(test_data)

    clock = timeit.Timer ( stmt ='sort_func ( copy ( data) ) ', 
                           globals ={ 'sort_func': sort_type ,
                            'data': test_data ,
                            'copy': copy.copy })
    n_ar , t_ar = clock.autorange ()
    t = clock.repeat ( repeat =7, number = n_ar )
    return t

# %%
def get_time_and_write_to_dataframe(Algorithm):
    time_data_points= []

    for i in (10,):
#               ,20,40,80,160,320,640,1280,2560,5120
#               ,10240,20480,40960,81920,163840,327680,655360,1310720
#               ,2621440,5242880,10485760,):
        time =   timing_function(i, Algorithm ) 
        for each_time in time:
#             print (each_time)
            time_data_points.append( {'Sort_Type':Algorithm.__name__ , 'Data_Type_or_List_type':'random'
           ,'List_length':i, 'Runtimes': each_time ,  'Number_of_repeatitions':'7'
           ,'Datetime':pd.Timestamp.now() } )
    return time_data_points

# %%
# Do not run this part if you don't want the data again
list_of_dict = get_time_and_write_to_dataframe(sorted)

# %%
df_= df_.append(list_of_dict)
df_
# Out:
#   Sort_Type Data_Type_or_List_type List_length  Runtimes  \
# 0    sorted                 random          10  0.261481
# 1    sorted                 random          10  0.259104
# 2    sorted                 random          10  0.277215
# 3    sorted                 random          10  0.223592
# 4    sorted                 random          10  0.298748
# 5    sorted                 random          10  0.355625
# 6    sorted                 random          10  0.291314
#
#   Number_of_repeatitions                   Datetime
# 0                      7 2019-10-31 16:27:01.404872
# 1                      7 2019-10-31 16:27:01.412872
# 2                      7 2019-10-31 16:27:01.412872
# 3                      7 2019-10-31 16:27:01.412872
# 4                      7 2019-10-31 16:27:01.412872
# 5                      7 2019-10-31 16:27:01.412872
# 6                      7 2019-10-31 16:27:01.412872

# %%
df_.to_csv (r'export_dataframe.csv', index = None, header=True)
df_
# Out:
#   Sort_Type Data_Type_or_List_type List_length  Runtimes  \
# 0    sorted                 random          10  0.261481
# 1    sorted                 random          10  0.259104
# 2    sorted                 random          10  0.277215
# 3    sorted                 random          10  0.223592
# 4    sorted                 random          10  0.298748
# 5    sorted                 random          10  0.355625
# 6    sorted                 random          10  0.291314
#
#   Number_of_repeatitions                   Datetime
# 0                      7 2019-10-31 16:27:01.404872
# 1                      7 2019-10-31 16:27:01.412872
# 2                      7 2019-10-31 16:27:01.412872
# 3                      7 2019-10-31 16:27:01.412872
# 4                      7 2019-10-31 16:27:01.412872
# 5                      7 2019-10-31 16:27:01.412872
# 6                      7 2019-10-31 16:27:01.412872

# %%
import pickle
name = 'data_frame.txt' 
f=open( name , 'ab')
pickle.dump(df_,f)
f.close()

# %%
read= pd.read_pickle("./data_frame.txt")
read
# Out:
#     Sort_Type Data_Type_or_List_type List_length   Runtimes  \
# 0      sorted                 random          10   0.262095
# 1      sorted                 random          10   0.214780
# 2      sorted                 random          10   0.221988
# 3      sorted                 random          10   0.249518
# 4      sorted                 random          10   0.248136
# 5      sorted                 random          10   0.179612
# 6      sorted                 random          10   0.270123
# 7      sorted                 random          20   0.201368
# 8      sorted                 random          20   0.211886
# 9      sorted                 random          20   0.199484
# 10     sorted                 random          20   0.183100
# 11     sorted                 random          20   0.178878
# 12     sorted                 random          20   0.177645
# 13     sorted                 random          20   0.171961
# 14     sorted                 random          40   0.293931
# 15     sorted                 random          40   0.261734
# 16     sorted                 random          40   0.227608
# 17     sorted                 random          40   0.226382
# 18     sorted                 random          40   0.232287
# 19     sorted                 random          40   0.235192
# 20     sorted                 random          40   0.191137
# 21     sorted                 random          80   0.183609
# 22     sorted                 random          80   0.179760
# 23     sorted                 random          80   0.181543
# 24     sorted                 random          80   0.167848
# 25     sorted                 random          80   0.167033
# 26     sorted                 random          80   0.163663
# 27     sorted                 random          80   0.162527
# 28     sorted                 random         160   0.341619
# 29     sorted                 random         160   0.326398
# ..        ...                    ...         ...        ...
# 117    sorted                 random      655360   1.860194
# 118    sorted                 random      655360   1.926612
# 119    sorted                 random     1310720   4.632213
# 120    sorted                 random     1310720   3.989324
# 121    sorted                 random     1310720   3.547645
# 122    sorted                 random     1310720   2.193859
# 123    sorted                 random     1310720   3.680475
# 124    sorted                 random     1310720   4.372878
# 125    sorted                 random     1310720   4.180261
# 126    sorted                 random     2621440   8.062219
# 127    sorted                 random     2621440   8.452458
# 128    sorted                 random     2621440   7.356156
# 129    sorted                 random     2621440   5.165356
# 130    sorted                 random     2621440   6.115122
# 131    sorted                 random     2621440   5.492347
# 132    sorted                 random     2621440   4.663801
# 133    sorted                 random     5242880  14.430511
# 134    sorted                 random     5242880  14.471754
# 135    sorted                 random     5242880  20.796006
# 136    sorted                 random     5242880  19.686528
# 137    sorted                 random     5242880  17.462381
# 138    sorted                 random     5242880  18.658763
# 139    sorted                 random     5242880  14.776938
# 140    sorted                 random    10485760  34.161587
# 141    sorted                 random    10485760  34.364720
# 142    sorted                 random    10485760  36.641354
# 143    sorted                 random    10485760  40.385404
# 144    sorted                 random    10485760  43.257374
# 145    sorted                 random    10485760  29.558077
# 146    sorted                 random    10485760  35.635236
#
#     Number_of_repeatitions                   Datetime
# 0                        7 2019-10-31 14:48:00.917440
